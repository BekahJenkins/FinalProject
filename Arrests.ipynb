# %%
import pandas as pd

# %%
raw_data = pd.read_csv("arrests.csv")

# %%
raw_data.head(10)
# Out:
#         PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
# 5  1974556  16144301  45.0      M    W  2016-08-15T13:30:00
# 6  1974628  16147655  29.0      M    W  2016-08-16T13:00:00
# 7  1974607  16146037  21.0      F    B  2016-08-16T04:25:00
# 8  1974643  16132537  17.0      M    B  2016-08-29T17:55:00
# 9  1974647  16138646  14.0      M    B  2016-08-23T13:36:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# ...

# %%
arrests = raw_data.groupby("INCIDENTNEIGHBORHOOD").count()

# %%
arrests.head(10)
# Out:
#                         PK   CCR   AGE  GENDER  RACE  ARRESTTIME  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center      1016  1016  1011    1016  1016        1016
# Allegheny West         109   109   108     109   109         109
# Allentown              805   805   799     805   805         805
# Arlington              250   250   249     250   250         250
# Arlington Heights      122   122   122     122   122         122
# Banksville             243   243   242     243   243         243
# Bedford Dwellings      530   530   528     530   530         530
# Beechview             1032  1032  1024    1032  1032        1032
# Beltzhoover            436   436   432     436   436         436
# Bloomfield             840   840   835     840   840         840
#
#                       ARRESTLOCATION  OFFENSES  INCIDENTLOCATION  \
# INCIDENTNEIGHBORHOOD
# Allegheny Center                1016      1016              1016
# Allegheny West                   109       109               109
# ...

# %%
arrests["Arrests"] = arrests["PK"]

# %%
arrests = arrests.drop(arrests.columns.difference(["Arrests"]), axis=1)

# %%
arrests.head(10)
# Out:
#                       Arrests
# INCIDENTNEIGHBORHOOD
# Allegheny Center         1016
# Allegheny West            109
# Allentown                 805
# Arlington                 250
# Arlington Heights         122
# Banksville                243
# Bedford Dwellings         530
# Beechview                1032
# Beltzhoover               436
# Bloomfield                840

# %%
arrests.sort_values(by=["Arrests"])
# Out:
#                            Arrests
# INCIDENTNEIGHBORHOOD
# Mt. Oliver Neighborhood          2
# Troy Hill-Herrs Island           6
# Mt. Oliver Boro                 18
# Central Northside               23
# Regent Square                   28
# ...                            ...
# Homewood South                1747
# East Allegheny                1777
# Carrick                       1963
# South Side Flats              2856
# Central Business District     3324
#
# [98 rows x 1 columns]

# %%
arrests = arrests.assign(ArreScore = pd.cut(data["CRASH_TOTAL"], bins = [0, 200, 1000, 10000, 100000], labels = ["4", "3", "2", "1"]))
