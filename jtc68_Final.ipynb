# %%
import pandas as pd
fac = pd.read_csv("facilities.csv", index_col="id")

# %%
fac.head()
# Out:
#     parcel_id inactive                                               name  \
# id
# 1   120-J-300        f                          57th Street Park Building
# 2     2-H-284        f                    Albert Turk Graham Park Shelter
# 3    23-R-157        f  Allegheny Northside Senior Center and Hazlett ...
# 4    10-F-198        f                            Ammon Recreation Center
# 5   013-K-314        f                    Arlington Field Lights Building
#
#    rentable     type                primary_user  address_number  \
# id
# 1         f  Storage  Department of Public Works             NaN
# 2         f  Shelter  Department of Public Works            39.0
# 3         t   Senior                   CitiParks             5.0
# 4         f     Pool                   CitiParks          2217.0
# 5         f  Utility                   CitiParks             0.0
#
#             street      zip  \
# id
# 1          57TH ST      NaN
# 2          VINE ST      NaN
# 3   ALLEGHENY SQ E  15212.0
# 4      BEDFORD AVE  15219.0
# 5      STERLING ST  15210.0
#
#                                                 image         neighborhood  \
# id
# 1   https://tools.wprdc.org/images/pittsburgh/faci...  Upper Lawrenceville
# 2   https://tools.wprdc.org/images/pittsburgh/faci...     Crawford-Roberts
# 3   https://tools.wprdc.org/images/pittsburgh/faci...     Allegheny Center
# 4   https://tools.wprdc.org/images/pittsburgh/faci...    Bedford Dwellings
# 5   https://tools.wprdc.org/images/pittsburgh/faci...    South Side Slopes
#
#     council_district  ward        tract  public_works_division  pli_division  \
# id
# 1                  7  10.0  42003101100                    2.0          10.0
# 2                  6   3.0  42003030500                    3.0           3.0
# 3                  1  22.0  42003562700                    1.0          22.0
# 4                  6   5.0  42003050900                    3.0           5.0
# 5                  3  16.0  42003160800                    3.0          16.0
#
#     police_zone fire_zone   latitude  longitude
# id
# 1           2.0     5-Mar  40.485666 -79.946450
# 2           2.0     1-Feb  40.440472 -79.984106
# 3           1.0     6-Jan  40.453099 -80.005343
# 4           2.0     5-Feb  40.448735 -79.977856
# 5           3.0    22-Apr  40.418152 -79.974471

# %%
fac.describe()
# Out:
#        address_number           zip  council_district        ward  \
# count      257.000000    229.000000        411.000000  410.000000
# mean      3773.891051  15218.318777          4.890511   16.568293
# std      28055.950384     67.319926          2.579503    8.326848
# min          0.000000  15201.000000          1.000000    1.000000
# 25%        414.000000  15207.000000          2.000000   11.000000
# 50%       1203.000000  15212.000000          5.000000   15.000000
# 75%       2217.000000  15219.000000          7.000000   24.000000
# max     450112.000000  16226.000000          9.000000   32.000000
#
#               tract  public_works_division  pli_division  police_zone  \
# count  4.110000e+02             410.000000    410.000000   410.000000
# mean   4.200340e+10               3.090244     16.568293     3.624390
# std    3.419258e+05               1.546082      8.326848     1.669631
# min    4.200301e+10               1.000000      1.000000     1.000000
# 25%    4.200313e+10               2.000000     11.000000     2.000000
# 50%    4.200327e+10               3.000000     15.000000     4.000000
# 75%    4.200356e+10               5.000000     24.000000     5.000000
# max    4.200398e+10               6.000000     32.000000     6.000000
#
#          latitude   longitude
# count  411.000000  411.000000
# mean    40.444639  -79.971633
# std      0.028454    0.048797
# min     40.369968  -80.080849
# 25%     40.426292  -80.009900
# 50%     40.449441  -79.976972
# 75%     40.465422  -79.926679
# max     40.492622  -79.870721

# %%
print(fac["type"].unique())
# Out:
# ['Storage' 'Shelter' 'Senior' 'Pool' 'Utility' 'Activity' 'Restrooms'
#  'Service' 'Concession' 'Dugout' 'Pool/Rec' 'Rec Center' 'Office'
#  'Pool Closed' 'Firehouse' 'Community' 'Vacant' 'Cabin' 'Medic Station'
#  'Training' 'Police' 'Salt Dome' 'Recycling' 'SERVICE' 'STORAGE' 'POLICE'
#  'TRAINING' 'OFFICE' nan]

# %%
fac['neighborhood'].value_counts()
# Out:
# Highland Park          30
# Squirrel Hill South    29
# Perry North            20
# Brookline              19
# Strip District         15
#                        ..
# Swisshelm Park          1
# East Allegheny          1
# Stanton Heights         1
# Bon Air                 1
# Fairywood               1
# Name: neighborhood, Length: 75, dtype: int64

# %%
fac['type'].value_counts()
# Out:
# Shelter          62
# Dugout           42
# Concession       32
# Firehouse        28
# Service          27
# Pool             25
# Storage          24
# Office           23
# Utility          19
# Activity         18
# Restrooms        18
# Senior           16
# Medic Station    11
# Salt Dome         8
# Police            8
# POLICE            7
# Pool/Rec          6
# STORAGE           6
# Rec Center        6
# Cabin             4
# Pool Closed       4
# Recycling         3
# SERVICE           3
# Community         3
# OFFICE            2
# TRAINING          2
# Training          2
# Vacant            1
# Name: type, dtype: int64
